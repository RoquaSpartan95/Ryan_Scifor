# %%
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt

# %%
us_babies = pd.read_csv("us_baby_names.csv")

# %%
us_babies
# Out:
#               Id       Name  Year Gender  Count
# 0              1       Mary  1880      F   7065
# 1              2       Anna  1880      F   2604
# 2              3       Emma  1880      F   2003
# 3              4  Elizabeth  1880      F   1939
# 4              5     Minnie  1880      F   1746
# ...          ...        ...   ...    ...    ...
# 1825428  1825429     Zykeem  2014      M      5
# 1825429  1825430     Zymeer  2014      M      5
# 1825430  1825431    Zymiere  2014      M      5
# 1825431  1825432      Zyran  2014      M      5
# 1825432  1825433      Zyrin  2014      M      5
#
# [1825433 rows x 5 columns]

# %%
sorted_us_babies = us_babies.sort_values('Count',ascending =False)

# %%
sorted_us_babies
# Out:
#               Id     Name  Year Gender  Count
# 431052    431053    Linda  1947      F  99680
# 441424    441425    Linda  1948      F  96205
# 437157    437158    James  1947      M  94755
# 544602    544603  Michael  1957      M  92709
# 437158    437159   Robert  1947      M  91642
# ...          ...      ...   ...    ...    ...
# 882783    882784    Marsh  1980      M      5
# 882784    882785   Marsha  1980      M      5
# 882785    882786  Marshel  1980      M      5
# 882786    882787  Marshon  1980      M      5
# 1825432  1825433    Zyrin  2014      M      5
#
# [1825433 rows x 5 columns]

# %%
ac=sorted_us_babies.head()

# %%
ac.boxplot(by ='Name', column =['Count'], grid = False)
# Out:
# <Axes: title={'center': 'Count'}, xlabel='Name'>

# %%
us_babies['Year']

# %%
us_babies['Year']==2014
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1825428     True
# 1825429     True
# 1825430     True
# 1825431     True
# 1825432     True
# Name: Year, Length: 1825433, dtype: bool

# %%
us_babies_2014 =us_babies.loc[us_babies['Year']==2014,:]

# %%
us_babies_2014
# Out:
#               Id      Name  Year Gender  Count
# 1792389  1792390      Emma  2014      F  20799
# 1792390  1792391    Olivia  2014      F  19674
# 1792391  1792392    Sophia  2014      F  18490
# 1792392  1792393  Isabella  2014      F  16950
# 1792393  1792394       Ava  2014      F  15586
# ...          ...       ...   ...    ...    ...
# 1825428  1825429    Zykeem  2014      M      5
# 1825429  1825430    Zymeer  2014      M      5
# 1825430  1825431   Zymiere  2014      M      5
# 1825431  1825432     Zyran  2014      M      5
# 1825432  1825433     Zyrin  2014      M      5
#
# [33044 rows x 5 columns]

# %%
sorted_us_2014 = us_babies_2014.sort_values('Count',ascending =False)

# %%
sorted_us_2014
# Out:
#               Id    Name  Year Gender  Count
# 1792389  1792390    Emma  2014      F  20799
# 1792390  1792391  Olivia  2014      F  19674
# 1811456  1811457    Noah  2014      M  19144
# 1792391  1792392  Sophia  2014      F  18490
# 1811457  1811458    Liam  2014      M  18342
# ...          ...     ...   ...    ...    ...
# 1810561  1810562   Melba  2014      F      5
# 1810560  1810561  Melaya  2014      F      5
# 1810559  1810560     Mel  2014      F      5
# 1810558  1810559   Mekhi  2014      F      5
# 1825432  1825433   Zyrin  2014      M      5
#
# [33044 rows x 5 columns]

# %%
most_popular_babies_names = sorted_us_2014.head()

# %%
most_popular_babies_names
# Out:
#               Id    Name  Year Gender  Count
# 1792389  1792390    Emma  2014      F  20799
# 1792390  1792391  Olivia  2014      F  19674
# 1811456  1811457    Noah  2014      M  19144
# 1792391  1792392  Sophia  2014      F  18490
# 1811457  1811458    Liam  2014      M  18342

# %%
sn.barplot(x='Name',y='Count', data = most_popular_babies_names,ci = False)
plt.show()
# Out:
# C:\Users\Russel\AppData\Local\Temp\ipykernel_20240\4086257492.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sn.barplot(x='Name',y='Count', data = most_popular_babies_names,ci = False)

# %%
us_Male=us_babies['Gender']=='M'

# %%
us_Male
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1825428     True
# 1825429     True
# 1825430     True
# 1825431     True
# 1825432     True
# Name: Gender, Length: 1825433, dtype: bool

# %%
us_babies_males =us_babies.loc[us_Male,:]

# %%
us_babies_males
# Out:
#               Id     Name  Year Gender  Count
# 942          943     John  1880      M   9655
# 943          944  William  1880      M   9532
# 944          945    James  1880      M   5927
# 945          946  Charles  1880      M   5348
# 946          947   George  1880      M   5126
# ...          ...      ...   ...    ...    ...
# 1825428  1825429   Zykeem  2014      M      5
# 1825429  1825430   Zymeer  2014      M      5
# 1825430  1825431  Zymiere  2014      M      5
# 1825431  1825432    Zyran  2014      M      5
# 1825432  1825433    Zyrin  2014      M      5
#
# [743750 rows x 5 columns]

# %%
popular_males=us_babies_males.sort_values('Count',ascending =False)

# %%
popular_males
# Out:
#               Id      Name  Year Gender  Count
# 437157    437158     James  1947      M  94755
# 544602    544603   Michael  1957      M  92709
# 437158    437159    Robert  1947      M  91642
# 533139    533140   Michael  1956      M  90633
# 556176    556177   Michael  1958      M  90519
# ...          ...       ...   ...    ...    ...
# 1093735  1093736    Moussa  1990      M      5
# 1093736  1093737  Moustafa  1990      M      5
# 1093737  1093738     Murry  1990      M      5
# 1093738  1093739     Myers  1990      M      5
# 1825432  1825433     Zyrin  2014      M      5
#
# [743750 rows x 5 columns]

# %%
ab=popular_males.head()

# %%
ab
# Out:
#             Id     Name  Year Gender  Count
# 437157  437158    James  1947      M  94755
# 544602  544603  Michael  1957      M  92709
# 437158  437159   Robert  1947      M  91642
# 533139  533140  Michael  1956      M  90633
# 556176  556177  Michael  1958      M  90519

# %%
x=ab["Name"]
y=ab["Count"]
plt.pie(y,labels=x,radius=1.2,shadow=True)
plt.show()

# %%
us_babies_females=us_babies.loc[us_babies['Gender']=='F',:]

# %%
us_babies_females
# Out:
#               Id       Name  Year Gender  Count
# 0              1       Mary  1880      F   7065
# 1              2       Anna  1880      F   2604
# 2              3       Emma  1880      F   2003
# 3              4  Elizabeth  1880      F   1939
# 4              5     Minnie  1880      F   1746
# ...          ...        ...   ...    ...    ...
# 1811451  1811452     Zyiona  2014      F      5
# 1811452  1811453   Zykeriah  2014      F      5
# 1811453  1811454     Zylynn  2014      F      5
# 1811454  1811455  Zyrihanna  2014      F      5
# 1811455  1811456    Zyriyah  2014      F      5
#
# [1081683 rows x 5 columns]

# %%
popular_females=us_babies_females.sort_values('Count',ascending =False)

# %%
popular_females
# Out:
#               Id     Name  Year Gender  Count
# 431052    431053    Linda  1947      F  99680
# 441424    441425    Linda  1948      F  96205
# 451659    451660    Linda  1949      F  91010
# 461921    461922    Linda  1950      F  80431
# 180215    180216     Mary  1921      F  73985
# ...          ...      ...   ...    ...    ...
# 1570619  1570620   Ahleah  2007      F      5
# 1570620  1570621  Ahleena  2007      F      5
# 1570621  1570622  Ahlyvia  2007      F      5
# 1570622  1570623     Ahmi  2007      F      5
# 1811455  1811456  Zyriyah  2014      F      5
#
# [1081683 rows x 5 columns]

# %%
pfh=popular_females.head()

# %%
pfh
# Out:
#             Id   Name  Year Gender  Count
# 431052  431053  Linda  1947      F  99680
# 441424  441425  Linda  1948      F  96205
# 451659  451660  Linda  1949      F  91010
# 461921  461922  Linda  1950      F  80431
# 180215  180216   Mary  1921      F  73985

# %%
x=pfh["Name"]
y=pfh["Count"]
plt.pie(y,labels=x,radius=1.2,shadow=True)
plt.show()
